# %%
# !pip install pandas
# !pip install albumentations
# !pip install rich

# %%
import os
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import glob
from rich import print
from ipywidgets import interact
from tqdm.auto import tqdm
import albumentations as A

SIZE=(360,360)

# %%
df_train = pd.read_csv("/root/train_fix_more_mask.csv")
df_train = df_train.sort_values(["id", "class"]).reset_index(drop = True)
df_train["patient"] = df_train.id.apply(lambda x: x.split("_")[0])
df_train["days"] = df_train.id.apply(lambda x: "_".join(x.split("_")[:2]))
num_slices = len(np.unique(df_train.id))
num_empty_slices = df_train.groupby("id").apply(lambda x: x.segmentation.isna().all()).sum()
num_patients = len(np.unique(df_train.patient))
num_days = len(np.unique(df_train.days))
print({
    "#slices:": num_slices,
    "#empty slices:": num_empty_slices,
    "#patients": num_patients,
    "#days": num_days
})
# Out:
# {'#slices:': 38496, '#empty slices:': 21079, '#patients': 85, '#days': 274}

# %%
all_image_files = sorted(glob.glob("/root/data/train/*/*/scans/*.png"), key = lambda x: x.split("/")[5] + "_" + x.split("/")[7])
size_x = [int(os.path.basename(_)[:-4].split("_")[-4]) for _ in all_image_files]
size_y = [int(os.path.basename(_)[:-4].split("_")[-3]) for _ in all_image_files]
spacing_x = [float(os.path.basename(_)[:-4].split("_")[-2]) for _ in all_image_files]
spacing_y = [float(os.path.basename(_)[:-4].split("_")[-1]) for _ in all_image_files]
df_train["image_files"] = np.repeat(all_image_files, 3)
df_train["spacing_x"] = np.repeat(spacing_x, 3)
df_train["spacing_y"] = np.repeat(spacing_y, 3)
df_train["size_x"] = np.repeat(size_x, 3)
df_train["size_y"] = np.repeat(size_y, 3)
df_train["slice"] = np.repeat([int(os.path.basename(_)[:-4].split("_")[-5]) for _ in all_image_files], 3)
df_train
# Out:
#                               id        class segmentation  patient  \
# 0       case101_day20_slice_0001  large_bowel          NaN  case101
# 1       case101_day20_slice_0001  small_bowel          NaN  case101
# 2       case101_day20_slice_0001      stomach          NaN  case101
# 3       case101_day20_slice_0002  large_bowel          NaN  case101
# 4       case101_day20_slice_0002  small_bowel          NaN  case101
# ...                          ...          ...          ...      ...
# 115483    case9_day22_slice_0143  small_bowel          NaN    case9
# 115484    case9_day22_slice_0143      stomach          NaN    case9
# 115485    case9_day22_slice_0144  large_bowel          NaN    case9
# 115486    case9_day22_slice_0144  small_bowel          NaN    case9
# 115487    case9_day22_slice_0144      stomach          NaN    case9
#
#                  days                                        image_files  \
# 0       case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 1       case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 2       case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 3       case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 4       case101_day20  /root/data/train/case101/case101_day20/scans/s...
# ...               ...                                                ...
# 115483    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 115484    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 115485    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 115486    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 115487    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
#
#         spacing_x  spacing_y  size_x  size_y  slice
# 0             1.5        1.5     266     266      1
# 1             1.5        1.5     266     266      1
# 2             1.5        1.5     266     266      1
# 3             1.5        1.5     266     266      2
# 4             1.5        1.5     266     266      2
# ...           ...        ...     ...     ...    ...
# 115483        1.5        1.5     360     310    143
# 115484        1.5        1.5     360     310    143
# 115485        1.5        1.5     360     310    144
# 115486        1.5        1.5     360     310    144
# 115487        1.5        1.5     360     310    144
#
# [115488 rows x 11 columns]

# %% [markdown]
# ### Remove Incorrect/Empty Annos

# %%
# from tqdm.notebook import tqdm
# df = df_train.copy()
# Case7 = []
# Case43 = []
# Case81 = []
# Case138 = []
# for i,row in tqdm(df_train.iterrows(), total=len(df_train)):
#     if row.id.rsplit("_",2)[0]=='case7_day0':
#         Case7.append(i)
#     elif row.id.rsplit("_",2)[0]=='case43_day18' or row.id.rsplit("_",2)[0]=='case43_day26':
#         Case43.append(i)
#     elif row.id.rsplit("_",2)[0]=='case81_day30':
#         Case81.append(i)
#     elif row.id.rsplit("_",2)[0]=='case138_day0':
#         Case138.append(i)
# print(len(Case7),len(Case43),len(Case138))
# df_train.drop(index=Case7+Case43+Case81+Case138 ,inplace=True)
# df_train = df_train.reset_index(drop=True)
df_train['empty'] = False
a = df_train.groupby('id').apply(lambda x: x.segmentation.isna().all())
for i in range(len(df_train)):
    df_train.loc[i,'empty'] = a[df_train.loc[i,'id']]
df_train = df_train[df_train['empty']==False].reset_index(drop=True)
df_train
# Out:
#                              id        class  \
# 0      case101_day20_slice_0066  large_bowel
# 1      case101_day20_slice_0066  small_bowel
# 2      case101_day20_slice_0066      stomach
# 3      case101_day20_slice_0067  large_bowel
# 4      case101_day20_slice_0067  small_bowel
# ...                         ...          ...
# 52246    case9_day22_slice_0121  small_bowel
# 52247    case9_day22_slice_0121      stomach
# 52248    case9_day22_slice_0122  large_bowel
# 52249    case9_day22_slice_0122  small_bowel
# 52250    case9_day22_slice_0122      stomach
#
#                                             segmentation  patient  \
# 0                                                    NaN  case101
# 1                                                    NaN  case101
# 2      32107 5 32371 10 32635 13 32900 15 33165 17 33...  case101
# 3                                                    NaN  case101
# 4                                                    NaN  case101
# ...                                                  ...      ...
# 52246  22080 8 22437 13 22794 17 23152 21 23510 24 23...    case9
# 52247                                                NaN    case9
# 52248  38018 9 38377 11 38737 11 39096 13 39456 13 39...    case9
# 52249  21361 3 21719 8 22078 10 22437 12 22795 15 231...    case9
# 52250                                                NaN    case9
#
#                 days                                        image_files  \
# 0      case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 1      case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 2      case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 3      case101_day20  /root/data/train/case101/case101_day20/scans/s...
# 4      case101_day20  /root/data/train/case101/case101_day20/scans/s...
# ...              ...                                                ...
# 52246    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 52247    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 52248    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 52249    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
# 52250    case9_day22  /root/data/train/case9/case9_day22/scans/slice...
#
#        spacing_x  spacing_y  size_x  size_y  slice  empty
# 0            1.5        1.5     266     266     66  False
# 1            1.5        1.5     266     266     66  False
# 2            1.5        1.5     266     266     66  False
# 3            1.5        1.5     266     266     67  False
# 4            1.5        1.5     266     266     67  False
# ...          ...        ...     ...     ...    ...    ...
# 52246        1.5        1.5     360     310    121  False
# 52247        1.5        1.5     360     310    121  False
# 52248        1.5        1.5     360     310    122  False
# 52249        1.5        1.5     360     310    122  False
# 52250        1.5        1.5     360     310    122  False
#
# [52251 rows x 12 columns]

# %%
from tqdm.notebook import tqdm
channels=3
strides=[6,0,-6]
for i in range(channels):
    df_train[f'image_path_{i:02}'] = df_train.groupby(['days'])['image_files'].shift(strides[i])#.fillna(method="ffill")
df_train['image_paths'] = df_train[[f'image_path_{i:02d}' for i in range(channels)]].values.tolist()
print(len(df_train))
for i,row in tqdm(df_train.iterrows(), total=len(df_train)):
    if type(row.image_paths[0]) == float:
        df_train.iloc[i].image_paths[0] = df_train.iloc[i].image_paths[1]
    if type(row.image_paths[-1]) == float:
        df_train.iloc[i].image_paths[-1] = df_train.iloc[i].image_paths[1]
df_train.image_paths[434]
# Out:
# 52251
#   0%|          | 0/52251 [00:00<?, ?it/s]
# ['/root/data/train/case101/case101_day26/scans/slice_0092_266_266_1.50_1.50.png',
#  '/root/data/train/case101/case101_day26/scans/slice_0094_266_266_1.50_1.50.png',
#  '/root/data/train/case101/case101_day26/scans/slice_0096_266_266_1.50_1.50.png']

# %%
def rle_decode(mask_rle, old_shape, new_shape):
    s = np.array(mask_rle.split(), dtype=int)
    starts, lengths = s[0::2] - 1, s[1::2]
    ends = starts + lengths
    h, w = old_shape
    mask = np.zeros((h * w,), dtype = np.uint8)
    for lo, hi in zip(starts, ends):
        mask[lo : hi] = 1
    mask = mask.reshape(old_shape)
    return mask
def load_img(path, new_shape=(320,320)):
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    old_shape = img.shape
    return img, old_shape
def rescale(img, masks, old_shape, new_shape):
    if old_shape==(234,234):
        img = cv2.resize(img,new_shape)
        masks = cv2.resize(masks,new_shape, interpolation=cv2.INTER_NEAREST)
    if old_shape==(266,266):
        img = cv2.resize(img,new_shape)
        masks = cv2.resize(masks,new_shape, interpolation=cv2.INTER_NEAREST)
    if old_shape==(276,276):
        img = cv2.resize(img,new_shape)
        masks = cv2.resize(masks,new_shape, interpolation=cv2.INTER_NEAREST)
    if old_shape==(310,360):
        img = np.pad(img,((25,25),(0,0),(0,0)),'constant')
        masks = np.pad(masks,((25,25),(0,0),(0,0)),'constant')
        img = cv2.resize(img,new_shape)
        masks = cv2.resize(masks,new_shape, interpolation=cv2.INTER_NEAREST)
    return img, masks

def display_pre(file_name, new_shape=(320,320)):
    norm = lambda x: ((x / (x.max()+1e-7))*255).astype(np.uint8)
    segms = df_train.loc[df_train.image_files == file_name]
    ori_shape = (segms.size_y.iloc[0], segms.size_x.iloc[0])
    img_paths = segms.image_paths.iloc[0]
    img = np.zeros((*ori_shape, len(img_paths)), dtype=np.uint16)
    for i, img_path in enumerate(img_paths):
        image,old_shape = load_img(img_path, new_shape)
        img[..., i]+=image
    img = norm(img)
    masks = img.copy().astype(np.uint8)
    for i, class_ in enumerate(['large_bowel', 'small_bowel', 'stomach']):
        cdf = segms[segms['class']==class_]
        rle = cdf.segmentation.squeeze()
        if len(cdf) and not pd.isna(rle):
            masks[..., i] = masks[...,i]/2+rle_decode(rle, old_shape, new_shape)*127
    img, masks = rescale(img, masks, old_shape, new_shape)
    img = np.concatenate([img, np.ones((img.shape[0], 10, 3), dtype = np.uint8) * 255, masks], 1)
    return img

# %%
# import albumentations as A
np.random.seed(2020)
print(df_train[["size_x", "size_y", "spacing_x", "spacing_y"]].value_counts())
for info, group in df_train.groupby(["size_x", "size_y", "spacing_x", "spacing_y"]):
    print(info)
    file_name = np.random.choice(group.loc[group.slice == 60, "image_files"])
    img = display_pre(file_name, SIZE)
    display(Image.fromarray(img))
# Out:
# size_x  size_y  spacing_x  spacing_y
# 266     266     1.50       1.50         34500
# 360     310     1.50       1.50         15285
# 276     276     1.63       1.63          2289
# 234     234     1.50       1.50           177
# dtype: int64
# (234, 234, 1.5, 1.5)
# <PIL.Image.Image image mode=RGB size=730x360 at 0x7F3F10627280>
# (266, 266, 1.5, 1.5)
# <PIL.Image.Image image mode=RGB size=730x360 at 0x7F3F178F9160>
# (276, 276, 1.63, 1.63)
# <PIL.Image.Image image mode=RGB size=730x360 at 0x7F3F10627BB0>
# (360, 310, 1.5, 1.5)
# <PIL.Image.Image image mode=RGB size=730x360 at 0x7F3F10627C40>

# %%
def show(idx):
    file_name = df_train.loc[idx, "image_files"]
    segms = df_train.loc[df_train.image_files == file_name]
    size = (segms.size_y.iloc[0], segms.size_x.iloc[0])
    print(size, segms.id)
    img = display_pre(file_name, SIZE)
    display(Image.fromarray(img))

@interact
def f(idx = (0, len(df_train) - 1, 3)):
    show(idx)
# Out:
# interactive(children=(IntSlider(value=26124, description='idx', max=52250, step=3), Output()), _dom_classes=('…

# %%
import os
os.makedirs('/root/autodl-tmp/mmseg_train_anno_ori/images')
os.makedirs('/root/autodl-tmp/mmseg_train_anno_ori/labels')
os.makedirs('/root/autodl-tmp/mmseg_train_anno_ori/splits')

# %%
for day, group in tqdm(df_train.groupby("days")):
    patient = group.patient.iloc[0]
    imgs = []
    msks = []
    for file_name in group.image_files.unique():
        segms = group.loc[group.image_files == file_name]
        ori_shape = (segms.size_y.iloc[0], segms.size_x.iloc[0])
        img_paths = segms.image_paths.iloc[0]
        img = np.zeros((*ori_shape, len(img_paths)), dtype=np.uint16)
        for i, img_path in enumerate(img_paths):
            image,old_shape = load_img(img_path, SIZE)
            img[..., i]+=image
#         new_shape = img.shape[:2]
        masks = np.zeros(img.shape, dtype=np.uint8)
        for i, class_ in enumerate(['large_bowel', 'small_bowel', 'stomach']):
            cdf = segms[segms['class']==class_]
            rle = cdf.segmentation.squeeze()
            if len(cdf) and not pd.isna(rle):
                masks[..., i] = rle_decode(rle, ori_shape, SIZE)
#         img, masks = rescale(img, masks, old_shape, SIZE)
        imgs.append(img)
        msks.append(masks)
    imgs = np.stack(imgs, 0)
    msks = np.stack(msks, 0)
    for i in range(msks.shape[0]):
        img = imgs[i]
        msk = msks[i]
        new_image_name = f"{day}_{i}.png"
        cv2.imwrite(f"/root/autodl-tmp/mmseg_train_anno_ori/images/{new_image_name}", img)
        cv2.imwrite(f"/root/autodl-tmp/mmseg_train_anno_ori/labels/{new_image_name}", msk)
# Out:
#   0%|          | 0/274 [00:00<?, ?it/s]

# %% [markdown]
# ### fold

# %%
all_image_files = glob.glob("/root/autodl-tmp/mmseg_train_anno_ori/labels/*")
masks = []
for i in range(len(all_image_files)):
    mask = cv2.imread(all_image_files[i])
    if mask.sum()==0:
        masks.append(0)
    else:
        masks.append(1)
patients = [os.path.basename(_).split("_")[0] for _ in all_image_files]

from sklearn.model_selection import GroupKFold, StratifiedGroupKFold
ctz = np.zeros(5)
cto = np.zeros(5)
split = list(StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=2022).split(patients, masks, groups=patients))
for fold, (train_idx, valid_idx) in enumerate(split):
    for i in valid_idx:
        if masks[i]==0:
            ctz[fold]+=1
        else:
            cto[fold]+=1
    with open(f"/root/autodl-tmp/mmseg_train_anno_ori/splits/fold_{fold}.txt", "w") as f:
        for idx in train_idx:
            f.write(os.path.basename(all_image_files[idx])[:-4] + "\n")
    with open(f"/root/autodl-tmp/mmseg_train_anno_ori/splits/valid_{fold}.txt", "w") as f:
        for idx in valid_idx:
            f.write(os.path.basename(all_image_files[idx])[:-4] + "\n")

# %%
print(ctz)
print(cto)
# Out:
# [0. 0. 0. 0. 0.]
# [3579. 3085. 3592. 3989. 3172.]

# %% [markdown]
# ## train all

# %%
all_image_files = glob.glob("/root/autodl-tmp/mmseg_train_anno_ori/labels/*")
masks = []
with open(f"/root/autodl-tmp/mmseg_train_anno_ori/splits/train_all.txt", "w") as f:
    for i in range(len(all_image_files)):
        f.write(os.path.basename(all_image_files[i])[:-4] + "\n")
