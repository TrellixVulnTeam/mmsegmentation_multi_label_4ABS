# %%
import cv2
import os, shutil
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
tqdm.pandas()
from scipy.ndimage import binary_closing, binary_opening, measurements
import cupy as cp
import sys
import gc
import matplotlib.pyplot as plt
from mmseg.apis import init_segmentor, inference_segmentor
from mmcv.utils import config

# %%
# df = pd.read_csv("/root/autodl-tmp/train.csv")
# df.iloc[74650:74670]

# %%
THRESHOD = [[0.9,0.5,0.5], [0.8,0.7,0.5]]
SIZE = 360
configs = [
    "/root/custom_cfg/Swin_Small_Uper.py",
]

ckpts = [
    "/root/Swin_Small_Uper/iter_50000.pth"
]

models = []
img_norm_cfg = dict(mean=[0,0,0], std=[1,1,1], to_rgb=False)
for cfg, ckpt, thrs in zip(configs, ckpts, THRESHOD):
    cfg = config.Config.fromfile(cfg)
    cfg.model.test_cfg.THRESHOD = thrs
    cfg.model.test_cfg.logits = False
    cfg.model.test_cfg.nature = False
    cfg.model.test_cfg.train_test = True
    cfg.model.test_cfg.multi_label = True
    cfg.data.test.pipeline[1].img_ratios=[1.0]
    cfg.data.test.pipeline[1].flip=False
    model = init_segmentor(cfg, ckpt, device='cuda:0')
    models.append(model)
# Out:
# load checkpoint from local path: /root/Swin_Small_Uper/iter_50000.pth

# %%
# df = pd.read_csv("/root/autodl-tmp/train.csv")
# for i in range(len(df)):
#     if df.loc[i,'id'].rsplit('_',2)[0]=='case43_day18' and df.loc[i,'class']=='large_bowel' and pd.isnull(df.loc[i,'segmentation'])!=True:
#         df.loc[i,'segmentation']=np.nan
#         break
# df.to_csv('/root/autodl-tmp/train.csv', index=False)

# %%
# df = pd.read_csv("/root/autodl-tmp/train.csv")
# df.drop(columns=['Unnamed: 0'],inplace=True)
# df.to_csv("/root/autodl-tmp/train.csv", index=False)

# %%
df = pd.read_csv("/root/autodl-tmp/train.csv")
df_train = df.copy()
df_train = df_train.sort_values(["id", "class"]).reset_index(drop = True)
df_train["patient"] = df_train.id.apply(lambda x: x.split("_")[0])
df_train["days"] = df_train.id.apply(lambda x: "_".join(x.split("_")[:2]))
num_slices = len(np.unique(df_train.id))
num_empty_slices = df_train.groupby("id").apply(lambda x: x.segmentation.isna().all()).sum()
num_patients = len(np.unique(df_train.patient))
num_days = len(np.unique(df_train.days))
print({
    "#slices:": num_slices,
    "#empty slices:": num_empty_slices,
    "#patients": num_patients,
    "#days": num_days
})
# Out:
# {'#slices:': 38496, '#empty slices:': 21906, '#patients': 85, '#days': 274}

# %%
all_image_files = sorted(glob("/root/autodl-tmp/train/*/*/scans/*.png"), key = lambda x: x.split("/")[5] + "_" + x.split("/")[7])
size_x = [int(os.path.basename(_)[:-4].split("_")[-4]) for _ in all_image_files]
size_y = [int(os.path.basename(_)[:-4].split("_")[-3]) for _ in all_image_files]
spacing_x = [float(os.path.basename(_)[:-4].split("_")[-2]) for _ in all_image_files]
spacing_y = [float(os.path.basename(_)[:-4].split("_")[-1]) for _ in all_image_files]
df_train["image_files"] = np.repeat(all_image_files, 3)
df_train["spacing_x"] = np.repeat(spacing_x, 3)
df_train["spacing_y"] = np.repeat(spacing_y, 3)
df_train["size_x"] = np.repeat(size_x, 3)
df_train["size_y"] = np.repeat(size_y, 3)
df_train["slice"] = np.repeat([int(os.path.basename(_)[:-4].split("_")[-5]) for _ in all_image_files], 3)
df_train
# Out:
#                               id        class segmentation  patient  \
# 0       case101_day20_slice_0001  large_bowel          NaN  case101
# 1       case101_day20_slice_0001  small_bowel          NaN  case101
# 2       case101_day20_slice_0001      stomach          NaN  case101
# 3       case101_day20_slice_0002  large_bowel          NaN  case101
# 4       case101_day20_slice_0002  small_bowel          NaN  case101
# ...                          ...          ...          ...      ...
# 115483    case9_day22_slice_0143  small_bowel          NaN    case9
# 115484    case9_day22_slice_0143      stomach          NaN    case9
# 115485    case9_day22_slice_0144  large_bowel          NaN    case9
# 115486    case9_day22_slice_0144  small_bowel          NaN    case9
# 115487    case9_day22_slice_0144      stomach          NaN    case9
#
#                  days                                        image_files  \
# 0       case101_day20  /root/autodl-tmp/train/case101/case101_day20/s...
# 1       case101_day20  /root/autodl-tmp/train/case101/case101_day20/s...
# 2       case101_day20  /root/autodl-tmp/train/case101/case101_day20/s...
# 3       case101_day20  /root/autodl-tmp/train/case101/case101_day20/s...
# 4       case101_day20  /root/autodl-tmp/train/case101/case101_day20/s...
# ...               ...                                                ...
# 115483    case9_day22  /root/autodl-tmp/train/case9/case9_day22/scans...
# 115484    case9_day22  /root/autodl-tmp/train/case9/case9_day22/scans...
# 115485    case9_day22  /root/autodl-tmp/train/case9/case9_day22/scans...
# 115486    case9_day22  /root/autodl-tmp/train/case9/case9_day22/scans...
# 115487    case9_day22  /root/autodl-tmp/train/case9/case9_day22/scans...
#
#         spacing_x  spacing_y  size_x  size_y  slice
# 0             1.5        1.5     266     266      1
# 1             1.5        1.5     266     266      1
# 2             1.5        1.5     266     266      1
# 3             1.5        1.5     266     266      2
# 4             1.5        1.5     266     266      2
# ...           ...        ...     ...     ...    ...
# 115483        1.5        1.5     360     310    143
# 115484        1.5        1.5     360     310    143
# 115485        1.5        1.5     360     310    144
# 115486        1.5        1.5     360     310    144
# 115487        1.5        1.5     360     310    144
#
# [115488 rows x 11 columns]

# %% [markdown]
# # Convert data to 2.5D

# %%
from tqdm.notebook import tqdm
channels=3
strides=[6,0,-6]
for i in range(channels):
    df_train[f'image_path_{i:02}'] = df_train.groupby(['days'])['image_files'].shift(strides[i])#.fillna(method="ffill")
df_train['image_paths'] = df_train[[f'image_path_{i:02d}' for i in range(channels)]].values.tolist()
print(len(df_train))
for i,row in tqdm(df_train.iterrows(), total=len(df_train)):
    if type(row.image_paths[0]) == float:
        df_train.iloc[i].image_paths[0] = df_train.iloc[i].image_paths[1]
    if type(row.image_paths[-1]) == float:
        df_train.iloc[i].image_paths[-1] = df_train.iloc[i].image_paths[1]
df_train.image_paths[434]
# Out:
# 115488
#   0%|          | 0/115488 [00:00<?, ?it/s]
# ['/root/autodl-tmp/train/case101/case101_day22/scans/slice_0001_266_266_1.50_1.50.png',
#  '/root/autodl-tmp/train/case101/case101_day22/scans/slice_0001_266_266_1.50_1.50.png',
#  '/root/autodl-tmp/train/case101/case101_day22/scans/slice_0003_266_266_1.50_1.50.png']

# %% [markdown]
# ### Remark wrong masks

# %%
re_mask_list = ['case7_day0', 'case43_day26', 'case81_day30', 'case138_day0']
id_ban = ['case7_day0', 'case81_day30']
rm_df_list = []
for idx, day_group in tqdm(df_train.groupby('days')):
    if day_group.days.iloc[0] in re_mask_list:
        rm_df_list.append(day_group)
rm_df = pd.concat(rm_df_list).reset_index(drop=True)
rm_df
# Out:
#   0%|          | 0/274 [00:00<?, ?it/s]
#                            id        class segmentation  patient  \
# 0     case138_day0_slice_0001  large_bowel          NaN  case138
# 1     case138_day0_slice_0001  small_bowel          NaN  case138
# 2     case138_day0_slice_0001      stomach          NaN  case138
# 3     case138_day0_slice_0002  large_bowel          NaN  case138
# 4     case138_day0_slice_0002  small_bowel          NaN  case138
# ...                       ...          ...          ...      ...
# 1723  case81_day30_slice_0143  small_bowel          NaN   case81
# 1724  case81_day30_slice_0143      stomach          NaN   case81
# 1725  case81_day30_slice_0144  large_bowel          NaN   case81
# 1726  case81_day30_slice_0144  small_bowel          NaN   case81
# 1727  case81_day30_slice_0144      stomach          NaN   case81
#
#               days                                        image_files  \
# 0     case138_day0  /root/autodl-tmp/train/case138/case138_day0/sc...
# 1     case138_day0  /root/autodl-tmp/train/case138/case138_day0/sc...
# 2     case138_day0  /root/autodl-tmp/train/case138/case138_day0/sc...
# 3     case138_day0  /root/autodl-tmp/train/case138/case138_day0/sc...
# 4     case138_day0  /root/autodl-tmp/train/case138/case138_day0/sc...
# ...            ...                                                ...
# 1723  case81_day30  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1724  case81_day30  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1725  case81_day30  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1726  case81_day30  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1727  case81_day30  /root/autodl-tmp/train/case81/case81_day30/sca...
#
#       spacing_x  spacing_y  size_x  size_y  slice  \
# 0           1.5        1.5     266     266      1
# 1           1.5        1.5     266     266      1
# 2           1.5        1.5     266     266      1
# 3           1.5        1.5     266     266      2
# 4           1.5        1.5     266     266      2
# ...         ...        ...     ...     ...    ...
# 1723        1.5        1.5     266     266    143
# 1724        1.5        1.5     266     266    143
# 1725        1.5        1.5     266     266    144
# 1726        1.5        1.5     266     266    144
# 1727        1.5        1.5     266     266    144
#
#                                           image_path_00  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1723  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1724  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1725  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1726  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1727  /root/autodl-tmp/train/case81/case81_day30/sca...
#
#                                           image_path_01  \
# 0     /root/autodl-tmp/train/case138/case138_day0/sc...
# 1     /root/autodl-tmp/train/case138/case138_day0/sc...
# 2     /root/autodl-tmp/train/case138/case138_day0/sc...
# 3     /root/autodl-tmp/train/case138/case138_day0/sc...
# 4     /root/autodl-tmp/train/case138/case138_day0/sc...
# ...                                                 ...
# 1723  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1724  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1725  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1726  /root/autodl-tmp/train/case81/case81_day30/sca...
# 1727  /root/autodl-tmp/train/case81/case81_day30/sca...
#
#                                           image_path_02  \
# 0     /root/autodl-tmp/train/case138/case138_day0/sc...
# 1     /root/autodl-tmp/train/case138/case138_day0/sc...
# 2     /root/autodl-tmp/train/case138/case138_day0/sc...
# 3     /root/autodl-tmp/train/case138/case138_day0/sc...
# 4     /root/autodl-tmp/train/case138/case138_day0/sc...
# ...                                                 ...
# 1723                                                NaN
# 1724                                                NaN
# 1725                                                NaN
# 1726                                                NaN
# 1727                                                NaN
#
#                                             image_paths
# 0     [/root/autodl-tmp/train/case138/case138_day0/s...
# 1     [/root/autodl-tmp/train/case138/case138_day0/s...
# 2     [/root/autodl-tmp/train/case138/case138_day0/s...
# 3     [/root/autodl-tmp/train/case138/case138_day0/s...
# 4     [/root/autodl-tmp/train/case138/case138_day0/s...
# ...                                                 ...
# 1723  [/root/autodl-tmp/train/case81/case81_day30/sc...
# 1724  [/root/autodl-tmp/train/case81/case81_day30/sc...
# 1725  [/root/autodl-tmp/train/case81/case81_day30/sc...
# 1726  [/root/autodl-tmp/train/case81/case81_day30/sc...
# 1727  [/root/autodl-tmp/train/case81/case81_day30/sc...
#
# [1728 rows x 15 columns]

# %% [markdown]
# ### Remark for 3 more slices

# %% [markdown]
# * ID, whose slices end up in 80
# * Case89:  day21
# * Case131: day15
# * Case117: day13 | day15 | day16 | day17
# * Case35:  day12 | day13 | day15 | day18
# * Case118: day0
# * Case146: day25
# * Case34:  day0 | day15 | day16

# %%
id_ban = []
list_80 = ['case89_day21', 'case131_day15', 'case117_day13','case117_day15', 'case117_day16',
           'case117_day17', 'case35_day12', 'case35_day13', 'case35_day15', 'case35_day18', 
           'case118_day0', 'case146_day25', 'case34_day0', 'case34_day15', 'case34_day16']
df_train['empty'] = False
a = df_train.groupby("id").apply(lambda x: x.segmentation.isna().all())
for i in range(len(df_train)):
    if df_train.loc[i,'slice']>50 and df_train.loc[i,'days'] in list_80:
        df_train.loc[i,'empty'] = a[df_train.loc[i,'id']]
    elif df_train.loc[i,'slice']>90:
        df_train.loc[i,'empty'] = a[df_train.loc[i,'id']]
rm_df = df_train[df_train['empty']==True].reset_index(drop=True)
rm_df = rm_df.groupby('days', as_index=False).apply(lambda x: x.iloc[:9,:]).reset_index().drop(columns=['level_0','level_1'])
re_mask_list = rm_df.id.unique().tolist()
rm_df

# %% [markdown]
# ### Load imgs and masks

# %%
def load_img(path, size=360):
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    img = img.astype(np.float32)
    ori_shape = img.shape[:2]
    new_shape = (size, size)
    if np.any(ori_shape!=new_shape):
        if ori_shape==(234,234):
            img = cv2.resize(img,new_shape)
        elif ori_shape==(266,266):
            img = cv2.resize(img,new_shape)
        elif ori_shape==(276,276):
            img = cv2.resize(img,new_shape)
        elif ori_shape==(310,360):
            img = np.pad(img,((25,25),(0,0)),'constant')
            img = cv2.resize(img,new_shape)
    return img, ori_shape

def load_imgs(img_paths, size=360):
    imgs = np.zeros((size, size, len(img_paths)), dtype=np.float32)
    for i, img_path in enumerate(img_paths):
        img, ori_shape  = load_img(img_path, size=size)
        imgs[..., i] = img
    imgs = imgs / (imgs.max()+1e-7)
    return imgs, ori_shape

def mask2rle(msk):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    msk    = cp.array(msk)
    pixels = msk.flatten()
    pad    = cp.array([0])
    pixels = cp.concatenate([pad, pixels, pad])
    runs   = cp.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def masks2rles(msks, ids, heights, widths):
    pred_strings = []; pred_ids = []; pred_classes = [];
    for idx in range(msks.shape[0]):
        msk = msks[idx]
        height = heights[idx].item()
        width = widths[idx].item()
        shape0 = (height, width)
        resize = (360, 360)
        if shape0!=resize:
            if shape0==(234,234):
                msk = cv2.resize(msk,shape0)
            if shape0==(266,266):
                msk = cv2.resize(msk,shape0)
            if shape0==(276,276):
                msk = cv2.resize(msk,shape0)
            if shape0==(310,360):
                msk = cv2.resize(msk,(shape0[0]+50,shape0[1]))
                msk = msk[25:335,:,:]
        rle = [None]*3
        for midx in [0, 1, 2]:
            rle[midx] = mask2rle(msk[...,midx])
        pred_strings.extend(rle)
        pred_ids.extend([ids[idx]]*len(rle))
        pred_classes.extend(['large_bowel', 'small_bowel', 'stomach'])
    return pred_strings, pred_ids, pred_classes

def rle_decode(mask_rle, ori_shape, new_shape):
    s = np.array(mask_rle.split(), dtype=int)
    starts, lengths = s[0::2] - 1, s[1::2]
    ends = starts + lengths
    h, w = ori_shape
    mask = np.zeros((h * w,), dtype = np.uint8)
    for lo, hi in zip(starts, ends):
        mask[lo : hi] = 1
    mask = mask.reshape(ori_shape)
    if np.any(ori_shape!=new_shape):
        if ori_shape==(234,234):
            mask = cv2.resize(mask,new_shape)
        elif ori_shape==(266,266):
            mask = cv2.resize(mask,new_shape)
        elif ori_shape==(276,276):
            mask = cv2.resize(mask,new_shape)
        elif ori_shape==(310,360):
            mask = np.pad(mask,((25,25),(0,0)),'constant')
            mask = cv2.resize(mask,new_shape)
    return mask

# %% [markdown]
# * Build Dataset

# %%
import torch
import torch.nn as F
from torch.utils.data import Dataset, DataLoader
import mmcv
from mmcv.parallel import collate, scatter
from mmseg.datasets.pipelines import Compose

class BuildDataset(torch.utils.data.Dataset):
    def __init__(self, df, size):
        self.df = df
        self.size = size
        self.img_paths = df['image_paths']
        self.ids       = df['id']
        self.rle       = df.groupby('id').apply(lambda x: x.segmentation.tolist())
        
    def __len__(self):
        return len(self.rle)
    
    def __getitem__(self, index):
        img_paths = self.img_paths[index*3]
        id_       = self.ids[index*3]
        mask_rle  = self.rle.loc[id_]
        
        img, ori_shape = load_imgs(img_paths, self.size)
        mask = np.zeros((self.size, self.size, 3))
        for i in range(3):
            rle = mask_rle[i]
            if not pd.isna(rle): #np.isnan(rle),pd.isnull(rle)
                mask[...,i] = rle_decode(rle, ori_shape, (self.size, self.size))
        h, w = ori_shape
        return img, mask, id_, h, w

# %% [markdown]
# * Inference

# %%
free_list = ['case7_day0_slice_0065', 'case7_day0_slice_0066', 'case7_day0_slice_0067',
             'case7_day0_slice_0068', 'case7_day0_slice_0069', 'case81_day30_slice_0063',
             'case81_day30_slice_0064', 'case81_day30_slice_0065']
ban_list = ['case7_day0_slice_0049', 'case7_day0_slice_0052']
def infer(model_paths, id_ban, test_loader):
    msks = []; imgs = []; ori_masks = []
    pred_strings = []; pred_ids = []; pred_classes = [];
    for (img, mask, ids, heights, widths) in tqdm(test_loader, total=len(test_loader), desc='Infer'):
        size = img.shape
        img = img.numpy()
        mask = mask.numpy()
        msk = np.zeros((size[0], size[1], size[2], 3))
        for model in model_paths:
            outs = np.zeros_like(msk)
            for im_idx in range(len(img)):
                outs[im_idx] = inference_segmentor(model, img[im_idx])[0]
                if mask[im_idx].sum()==0 and ids[im_idx] not in free_list:
                    outs[im_idx] = mask[im_idx]
                elif ids[im_idx].rsplit('_',2)[0] not in id_ban:
                    outs[im_idx,:,:,1:] = mask[im_idx,:,:,1:]
                elif ids[im_idx] in ban_list:
                    outs[im_idx] = 0
            msk += outs/len(model_paths)
        msk[...,0] = msk[...,0] > 0.95
        msk[...,1] = msk[...,1] > 0.70
        msk[...,2] = msk[...,2] > 0.60
        msk = msk.astype(np.uint8)
        
        imgs.append((img*255).astype(np.uint8))
        msks.append(msk*255)
        ori_masks.append((mask*255).astype(np.uint8))
        result = masks2rles(msk, ids, heights, widths)
        pred_strings.extend(result[0])
        pred_ids.extend(result[1])
        pred_classes.extend(result[2])
        del img, msk, outs, model, result, mask
        gc.collect()
    return pred_strings, pred_ids, pred_classes, imgs, msks, ori_masks

# %%
from tqdm import tqdm
test_dataset = BuildDataset(rm_df, SIZE)
test_loader  = DataLoader(test_dataset, batch_size=64, num_workers=1, shuffle=False, pin_memory=False)
pred_strings, pred_ids, pred_classes, imgs, msks, ori_masks = infer(models, id_ban, test_loader)
# Out:
# Infer: 100%|██████████| 9/9 [00:33<00:00,  3.69s/it]

# %%
# !mkdir -p /root/save_pred/imgs
# !mkdir -p /root/save_pred/msks
# !mkdir -p /root/save_pred/ori_msks

# %%
imgs = np.concatenate(imgs)
msks = np.concatenate(msks)
ori_masks = np.concatenate(ori_masks)
idx = 0
imgs = imgs[...,::-1]
msks = msks[...,::-1]
ori_masks = ori_masks[...,::-1]
for img, msk, ori_msk in zip(imgs, msks, ori_masks):
    msk = 0.4*img+0.6*msk
    ori_msk = 0.4*img+0.6*ori_msk
    cv2.imwrite(f'/root/save_pred/imgs/{pred_ids[idx]}.png', img)
    cv2.imwrite(f'/root/save_pred/msks/{pred_ids[idx]}.png', msk)
    cv2.imwrite(f'/root/save_pred/ori_msks/{pred_ids[idx]}.png', ori_msk)
    idx += 3

# %%
for img, msk, ori_msk in zip(imgs, msks, ori_masks):
    for i in range(len(img)):
        if msk[i].sum()>0:
            plt.figure(figsize=(12, 7))
            plt.subplot(1, 3, 1); plt.imshow(img[i], cmap='bone'); plt.axis('OFF'); plt.title('image')
            plt.subplot(1, 3, 2); plt.imshow(img[i], cmap='bone'); plt.imshow(msk[i], alpha=0.6); plt.axis('OFF'); plt.title('pre_mask')
            plt.subplot(1, 3, 3); plt.imshow(img[i], cmap='bone'); plt.imshow(ori_msk[i], alpha=0.6); plt.axis('OFF'); plt.title('ori_mask')
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Csv for wrong slices

# %%
def fix_mask(row):
    if row.id.rsplit('_',2)[0] in re_mask_list:
        for i in range(len(pred_strings)):
            
            if row.id.rsplit('_',2)[0] in id_ban:
                if row.id == pred_ids[i] and row['class'] == pred_classes[i]:
                    row.segmentation = pred_strings[i]
                    print(f'fix_wrong_{row.id}')
                    break
            elif row['class']=='large_bowel' and pd.isnull(row.segmentation):
                if row.id == pred_ids[i] and row['class'] == pred_classes[i]:
                    row.segmentation = pred_strings[i]
                    print(f'fix_empty_{row.id}')
                    break
    return row
fix_df = df.apply(fix_mask, axis=1)
fix_df.to_csv('/root/autodl-tmp/train_fix.csv',index=False)
fix_df.head(5)
# Out:
# fix_wrong_case7_day0_slice_0001
# fix_wrong_case7_day0_slice_0001
# fix_wrong_case7_day0_slice_0001
# fix_wrong_case7_day0_slice_0002
# fix_wrong_case7_day0_slice_0002
# fix_wrong_case7_day0_slice_0002
# fix_wrong_case7_day0_slice_0003
# fix_wrong_case7_day0_slice_0003
# fix_wrong_case7_day0_slice_0003
# fix_wrong_case7_day0_slice_0004
# fix_wrong_case7_day0_slice_0004
# fix_wrong_case7_day0_slice_0004
# fix_wrong_case7_day0_slice_0005
# fix_wrong_case7_day0_slice_0005
# fix_wrong_case7_day0_slice_0005
# fix_wrong_case7_day0_slice_0006
# fix_wrong_case7_day0_slice_0006
# fix_wrong_case7_day0_slice_0006
# fix_wrong_case7_day0_slice_0007
# fix_wrong_case7_day0_slice_0007
# fix_wrong_case7_day0_slice_0007
# fix_wrong_case7_day0_slice_0008
# fix_wrong_case7_day0_slice_0008
# fix_wrong_case7_day0_slice_0008
# fix_wrong_case7_day0_slice_0009
# fix_wrong_case7_day0_slice_0009
# fix_wrong_case7_day0_slice_0009
# fix_wrong_case7_day0_slice_0010
# fix_wrong_case7_day0_slice_0010
# fix_wrong_case7_day0_slice_0010
# fix_wrong_case7_day0_slice_0011
# fix_wrong_case7_day0_slice_0011
# fix_wrong_case7_day0_slice_0011
# fix_wrong_case7_day0_slice_0012
# fix_wrong_case7_day0_slice_0012
# fix_wrong_case7_day0_slice_0012
# fix_wrong_case7_day0_slice_0013
# fix_wrong_case7_day0_slice_0013
# fix_wrong_case7_day0_slice_0013
# fix_wrong_case7_day0_slice_0014
# fix_wrong_case7_day0_slice_0014
# fix_wrong_case7_day0_slice_0014
# fix_wrong_case7_day0_slice_0015
# fix_wrong_case7_day0_slice_0015
# fix_wrong_case7_day0_slice_0015
# fix_wrong_case7_day0_slice_0016
# fix_wrong_case7_day0_slice_0016
# fix_wrong_case7_day0_slice_0016
# fix_wrong_case7_day0_slice_0017
# fix_wrong_case7_day0_slice_0017
# fix_wrong_case7_day0_slice_0017
# fix_wrong_case7_day0_slice_0018
# fix_wrong_case7_day0_slice_0018
# fix_wrong_case7_day0_slice_0018
# fix_wrong_case7_day0_slice_0019
# fix_wrong_case7_day0_slice_0019
# fix_wrong_case7_day0_slice_0019
# fix_wrong_case7_day0_slice_0020
# fix_wrong_case7_day0_slice_0020
# fix_wrong_case7_day0_slice_0020
# fix_wrong_case7_day0_slice_0021
# fix_wrong_case7_day0_slice_0021
# fix_wrong_case7_day0_slice_0021
# fix_wrong_case7_day0_slice_0022
# fix_wrong_case7_day0_slice_0022
# fix_wrong_case7_day0_slice_0022
# fix_wrong_case7_day0_slice_0023
# fix_wrong_case7_day0_slice_0023
# fix_wrong_case7_day0_slice_0023
# fix_wrong_case7_day0_slice_0024
# fix_wrong_case7_day0_slice_0024
# fix_wrong_case7_day0_slice_0024
# fix_wrong_case7_day0_slice_0025
# fix_wrong_case7_day0_slice_0025
# fix_wrong_case7_day0_slice_0025
# fix_wrong_case7_day0_slice_0026
# fix_wrong_case7_day0_slice_0026
# fix_wrong_case7_day0_slice_0026
# fix_wrong_case7_day0_slice_0027
# fix_wrong_case7_day0_slice_0027
# fix_wrong_case7_day0_slice_0027
# fix_wrong_case7_day0_slice_0028
# fix_wrong_case7_day0_slice_0028
# fix_wrong_case7_day0_slice_0028
# fix_wrong_case7_day0_slice_0029
# fix_wrong_case7_day0_slice_0029
# fix_wrong_case7_day0_slice_0029
# fix_wrong_case7_day0_slice_0030
# fix_wrong_case7_day0_slice_0030
# fix_wrong_case7_day0_slice_0030
# fix_wrong_case7_day0_slice_0031
# fix_wrong_case7_day0_slice_0031
# fix_wrong_case7_day0_slice_0031
# fix_wrong_case7_day0_slice_0032
# fix_wrong_case7_day0_slice_0032
# fix_wrong_case7_day0_slice_0032
# fix_wrong_case7_day0_slice_0033
# fix_wrong_case7_day0_slice_0033
# fix_wrong_case7_day0_slice_0033
# fix_wrong_case7_day0_slice_0034
# fix_wrong_case7_day0_slice_0034
# fix_wrong_case7_day0_slice_0034
# fix_wrong_case7_day0_slice_0035
# fix_wrong_case7_day0_slice_0035
# fix_wrong_case7_day0_slice_0035
# fix_wrong_case7_day0_slice_0036
# fix_wrong_case7_day0_slice_0036
# fix_wrong_case7_day0_slice_0036
# fix_wrong_case7_day0_slice_0037
# fix_wrong_case7_day0_slice_0037
# fix_wrong_case7_day0_slice_0037
# fix_wrong_case7_day0_slice_0038
# fix_wrong_case7_day0_slice_0038
# fix_wrong_case7_day0_slice_0038
# fix_wrong_case7_day0_slice_0039
# fix_wrong_case7_day0_slice_0039
# fix_wrong_case7_day0_slice_0039
# fix_wrong_case7_day0_slice_0040
# fix_wrong_case7_day0_slice_0040
# fix_wrong_case7_day0_slice_0040
# fix_wrong_case7_day0_slice_0041
# fix_wrong_case7_day0_slice_0041
# fix_wrong_case7_day0_slice_0041
# fix_wrong_case7_day0_slice_0042
# fix_wrong_case7_day0_slice_0042
# fix_wrong_case7_day0_slice_0042
# fix_wrong_case7_day0_slice_0043
# fix_wrong_case7_day0_slice_0043
# fix_wrong_case7_day0_slice_0043
# fix_wrong_case7_day0_slice_0044
# fix_wrong_case7_day0_slice_0044
# fix_wrong_case7_day0_slice_0044
# fix_wrong_case7_day0_slice_0045
# fix_wrong_case7_day0_slice_0045
# fix_wrong_case7_day0_slice_0045
# fix_wrong_case7_day0_slice_0046
# fix_wrong_case7_day0_slice_0046
# fix_wrong_case7_day0_slice_0046
# fix_wrong_case7_day0_slice_0047
# fix_wrong_case7_day0_slice_0047
# fix_wrong_case7_day0_slice_0047
# fix_wrong_case7_day0_slice_0048
# fix_wrong_case7_day0_slice_0048
# fix_wrong_case7_day0_slice_0048
# fix_wrong_case7_day0_slice_0049
# fix_wrong_case7_day0_slice_0049
# fix_wrong_case7_day0_slice_0049
# fix_wrong_case7_day0_slice_0050
# fix_wrong_case7_day0_slice_0050
# fix_wrong_case7_day0_slice_0050
# fix_wrong_case7_day0_slice_0051
# fix_wrong_case7_day0_slice_0051
# fix_wrong_case7_day0_slice_0051
# fix_wrong_case7_day0_slice_0052
# fix_wrong_case7_day0_slice_0052
# fix_wrong_case7_day0_slice_0052
# fix_wrong_case7_day0_slice_0053
# fix_wrong_case7_day0_slice_0053
# fix_wrong_case7_day0_slice_0053
# fix_wrong_case7_day0_slice_0054
# fix_wrong_case7_day0_slice_0054
# fix_wrong_case7_day0_slice_0054
# fix_wrong_case7_day0_slice_0055
# fix_wrong_case7_day0_slice_0055
# fix_wrong_case7_day0_slice_0055
# fix_wrong_case7_day0_slice_0056
# fix_wrong_case7_day0_slice_0056
# fix_wrong_case7_day0_slice_0056
# fix_wrong_case7_day0_slice_0057
# fix_wrong_case7_day0_slice_0057
# fix_wrong_case7_day0_slice_0057
# fix_wrong_case7_day0_slice_0058
# fix_wrong_case7_day0_slice_0058
# fix_wrong_case7_day0_slice_0058
# fix_wrong_case7_day0_slice_0059
# fix_wrong_case7_day0_slice_0059
# fix_wrong_case7_day0_slice_0059
# fix_wrong_case7_day0_slice_0060
# fix_wrong_case7_day0_slice_0060
# fix_wrong_case7_day0_slice_0060
# fix_wrong_case7_day0_slice_0061
# fix_wrong_case7_day0_slice_0061
# fix_wrong_case7_day0_slice_0061
# fix_wrong_case7_day0_slice_0062
# fix_wrong_case7_day0_slice_0062
# fix_wrong_case7_day0_slice_0062
# fix_wrong_case7_day0_slice_0063
# fix_wrong_case7_day0_slice_0063
# fix_wrong_case7_day0_slice_0063
# fix_wrong_case7_day0_slice_0064
# fix_wrong_case7_day0_slice_0064
# fix_wrong_case7_day0_slice_0064
# fix_wrong_case7_day0_slice_0065
# fix_wrong_case7_day0_slice_0065
# fix_wrong_case7_day0_slice_0065
# fix_wrong_case7_day0_slice_0066
# fix_wrong_case7_day0_slice_0066
# fix_wrong_case7_day0_slice_0066
# fix_wrong_case7_day0_slice_0067
# fix_wrong_case7_day0_slice_0067
# fix_wrong_case7_day0_slice_0067
# fix_wrong_case7_day0_slice_0068
# fix_wrong_case7_day0_slice_0068
# fix_wrong_case7_day0_slice_0068
# fix_wrong_case7_day0_slice_0069
# fix_wrong_case7_day0_slice_0069
# fix_wrong_case7_day0_slice_0069
# fix_wrong_case7_day0_slice_0070
# fix_wrong_case7_day0_slice_0070
# fix_wrong_case7_day0_slice_0070
# fix_wrong_case7_day0_slice_0071
# fix_wrong_case7_day0_slice_0071
# fix_wrong_case7_day0_slice_0071
# fix_wrong_case7_day0_slice_0072
# fix_wrong_case7_day0_slice_0072
# fix_wrong_case7_day0_slice_0072
# fix_wrong_case7_day0_slice_0073
# fix_wrong_case7_day0_slice_0073
# fix_wrong_case7_day0_slice_0073
# fix_wrong_case7_day0_slice_0074
# fix_wrong_case7_day0_slice_0074
# fix_wrong_case7_day0_slice_0074
# fix_wrong_case7_day0_slice_0075
# fix_wrong_case7_day0_slice_0075
# fix_wrong_case7_day0_slice_0075
# fix_wrong_case7_day0_slice_0076
# fix_wrong_case7_day0_slice_0076
# fix_wrong_case7_day0_slice_0076
# fix_wrong_case7_day0_slice_0077
# fix_wrong_case7_day0_slice_0077
# fix_wrong_case7_day0_slice_0077
# fix_wrong_case7_day0_slice_0078
# fix_wrong_case7_day0_slice_0078
# fix_wrong_case7_day0_slice_0078
# fix_wrong_case7_day0_slice_0079
# fix_wrong_case7_day0_slice_0079
# fix_wrong_case7_day0_slice_0079
# fix_wrong_case7_day0_slice_0080
# fix_wrong_case7_day0_slice_0080
# fix_wrong_case7_day0_slice_0080
# fix_wrong_case7_day0_slice_0081
# fix_wrong_case7_day0_slice_0081
# fix_wrong_case7_day0_slice_0081
# fix_wrong_case7_day0_slice_0082
# fix_wrong_case7_day0_slice_0082
# fix_wrong_case7_day0_slice_0082
# fix_wrong_case7_day0_slice_0083
# fix_wrong_case7_day0_slice_0083
# fix_wrong_case7_day0_slice_0083
# fix_wrong_case7_day0_slice_0084
# fix_wrong_case7_day0_slice_0084
# fix_wrong_case7_day0_slice_0084
# fix_wrong_case7_day0_slice_0085
# fix_wrong_case7_day0_slice_0085
# fix_wrong_case7_day0_slice_0085
# fix_wrong_case7_day0_slice_0086
# fix_wrong_case7_day0_slice_0086
# fix_wrong_case7_day0_slice_0086
# fix_wrong_case7_day0_slice_0087
# fix_wrong_case7_day0_slice_0087
# fix_wrong_case7_day0_slice_0087
# fix_wrong_case7_day0_slice_0088
# fix_wrong_case7_day0_slice_0088
# fix_wrong_case7_day0_slice_0088
# fix_wrong_case7_day0_slice_0089
# fix_wrong_case7_day0_slice_0089
# fix_wrong_case7_day0_slice_0089
# fix_wrong_case7_day0_slice_0090
# fix_wrong_case7_day0_slice_0090
# fix_wrong_case7_day0_slice_0090
# fix_wrong_case7_day0_slice_0091
# fix_wrong_case7_day0_slice_0091
# fix_wrong_case7_day0_slice_0091
# fix_wrong_case7_day0_slice_0092
# fix_wrong_case7_day0_slice_0092
# fix_wrong_case7_day0_slice_0092
# fix_wrong_case7_day0_slice_0093
# fix_wrong_case7_day0_slice_0093
# fix_wrong_case7_day0_slice_0093
# fix_wrong_case7_day0_slice_0094
# fix_wrong_case7_day0_slice_0094
# fix_wrong_case7_day0_slice_0094
# fix_wrong_case7_day0_slice_0095
# fix_wrong_case7_day0_slice_0095
# fix_wrong_case7_day0_slice_0095
# fix_wrong_case7_day0_slice_0096
# fix_wrong_case7_day0_slice_0096
# fix_wrong_case7_day0_slice_0096
# fix_wrong_case7_day0_slice_0097
# fix_wrong_case7_day0_slice_0097
# fix_wrong_case7_day0_slice_0097
# fix_wrong_case7_day0_slice_0098
# fix_wrong_case7_day0_slice_0098
# fix_wrong_case7_day0_slice_0098
# fix_wrong_case7_day0_slice_0099
# fix_wrong_case7_day0_slice_0099
# fix_wrong_case7_day0_slice_0099
# fix_wrong_case7_day0_slice_0100
# fix_wrong_case7_day0_slice_0100
# fix_wrong_case7_day0_slice_0100
# fix_wrong_case7_day0_slice_0101
# fix_wrong_case7_day0_slice_0101
# fix_wrong_case7_day0_slice_0101
# fix_wrong_case7_day0_slice_0102
# fix_wrong_case7_day0_slice_0102
# fix_wrong_case7_day0_slice_0102
# fix_wrong_case7_day0_slice_0103
# fix_wrong_case7_day0_slice_0103
# fix_wrong_case7_day0_slice_0103
# fix_wrong_case7_day0_slice_0104
# fix_wrong_case7_day0_slice_0104
# fix_wrong_case7_day0_slice_0104
# fix_wrong_case7_day0_slice_0105
# fix_wrong_case7_day0_slice_0105
# fix_wrong_case7_day0_slice_0105
# fix_wrong_case7_day0_slice_0106
# fix_wrong_case7_day0_slice_0106
# fix_wrong_case7_day0_slice_0106
# fix_wrong_case7_day0_slice_0107
# fix_wrong_case7_day0_slice_0107
# fix_wrong_case7_day0_slice_0107
# fix_wrong_case7_day0_slice_0108
# fix_wrong_case7_day0_slice_0108
# fix_wrong_case7_day0_slice_0108
# fix_wrong_case7_day0_slice_0109
# fix_wrong_case7_day0_slice_0109
# fix_wrong_case7_day0_slice_0109
# fix_wrong_case7_day0_slice_0110
# fix_wrong_case7_day0_slice_0110
# fix_wrong_case7_day0_slice_0110
# fix_wrong_case7_day0_slice_0111
# fix_wrong_case7_day0_slice_0111
# fix_wrong_case7_day0_slice_0111
# fix_wrong_case7_day0_slice_0112
# fix_wrong_case7_day0_slice_0112
# fix_wrong_case7_day0_slice_0112
# fix_wrong_case7_day0_slice_0113
# fix_wrong_case7_day0_slice_0113
# fix_wrong_case7_day0_slice_0113
# fix_wrong_case7_day0_slice_0114
# fix_wrong_case7_day0_slice_0114
# fix_wrong_case7_day0_slice_0114
# fix_wrong_case7_day0_slice_0115
# fix_wrong_case7_day0_slice_0115
# fix_wrong_case7_day0_slice_0115
# fix_wrong_case7_day0_slice_0116
# fix_wrong_case7_day0_slice_0116
# fix_wrong_case7_day0_slice_0116
# fix_wrong_case7_day0_slice_0117
# fix_wrong_case7_day0_slice_0117
# fix_wrong_case7_day0_slice_0117
# fix_wrong_case7_day0_slice_0118
# fix_wrong_case7_day0_slice_0118
# fix_wrong_case7_day0_slice_0118
# fix_wrong_case7_day0_slice_0119
# fix_wrong_case7_day0_slice_0119
# fix_wrong_case7_day0_slice_0119
# fix_wrong_case7_day0_slice_0120
# fix_wrong_case7_day0_slice_0120
# fix_wrong_case7_day0_slice_0120
# fix_wrong_case7_day0_slice_0121
# fix_wrong_case7_day0_slice_0121
# fix_wrong_case7_day0_slice_0121
# fix_wrong_case7_day0_slice_0122
# fix_wrong_case7_day0_slice_0122
# fix_wrong_case7_day0_slice_0122
# fix_wrong_case7_day0_slice_0123
# fix_wrong_case7_day0_slice_0123
# fix_wrong_case7_day0_slice_0123
# fix_wrong_case7_day0_slice_0124
# fix_wrong_case7_day0_slice_0124
# fix_wrong_case7_day0_slice_0124
# fix_wrong_case7_day0_slice_0125
# fix_wrong_case7_day0_slice_0125
# fix_wrong_case7_day0_slice_0125
# fix_wrong_case7_day0_slice_0126
# fix_wrong_case7_day0_slice_0126
# fix_wrong_case7_day0_slice_0126
# fix_wrong_case7_day0_slice_0127
# fix_wrong_case7_day0_slice_0127
# fix_wrong_case7_day0_slice_0127
# fix_wrong_case7_day0_slice_0128
# fix_wrong_case7_day0_slice_0128
# fix_wrong_case7_day0_slice_0128
# fix_wrong_case7_day0_slice_0129
# fix_wrong_case7_day0_slice_0129
# fix_wrong_case7_day0_slice_0129
# fix_wrong_case7_day0_slice_0130
# fix_wrong_case7_day0_slice_0130
# fix_wrong_case7_day0_slice_0130
# fix_wrong_case7_day0_slice_0131
# fix_wrong_case7_day0_slice_0131
# fix_wrong_case7_day0_slice_0131
# fix_wrong_case7_day0_slice_0132
# fix_wrong_case7_day0_slice_0132
# fix_wrong_case7_day0_slice_0132
# fix_wrong_case7_day0_slice_0133
# fix_wrong_case7_day0_slice_0133
# fix_wrong_case7_day0_slice_0133
# fix_wrong_case7_day0_slice_0134
# fix_wrong_case7_day0_slice_0134
# fix_wrong_case7_day0_slice_0134
# fix_wrong_case7_day0_slice_0135
# fix_wrong_case7_day0_slice_0135
# fix_wrong_case7_day0_slice_0135
# fix_wrong_case7_day0_slice_0136
# fix_wrong_case7_day0_slice_0136
# fix_wrong_case7_day0_slice_0136
# fix_wrong_case7_day0_slice_0137
# fix_wrong_case7_day0_slice_0137
# fix_wrong_case7_day0_slice_0137
# fix_wrong_case7_day0_slice_0138
# fix_wrong_case7_day0_slice_0138
# fix_wrong_case7_day0_slice_0138
# fix_wrong_case7_day0_slice_0139
# fix_wrong_case7_day0_slice_0139
# fix_wrong_case7_day0_slice_0139
# fix_wrong_case7_day0_slice_0140
# fix_wrong_case7_day0_slice_0140
# fix_wrong_case7_day0_slice_0140
# fix_wrong_case7_day0_slice_0141
# fix_wrong_case7_day0_slice_0141
# fix_wrong_case7_day0_slice_0141
# fix_wrong_case7_day0_slice_0142
# fix_wrong_case7_day0_slice_0142
# fix_wrong_case7_day0_slice_0142
# fix_wrong_case7_day0_slice_0143
# fix_wrong_case7_day0_slice_0143
# fix_wrong_case7_day0_slice_0143
# fix_wrong_case7_day0_slice_0144
# fix_wrong_case7_day0_slice_0144
# fix_wrong_case7_day0_slice_0144
# fix_empty_case43_day26_slice_0001
# fix_empty_case43_day26_slice_0002
# fix_empty_case43_day26_slice_0003
# fix_empty_case43_day26_slice_0004
# fix_empty_case43_day26_slice_0005
# fix_empty_case43_day26_slice_0006
# fix_empty_case43_day26_slice_0007
# fix_empty_case43_day26_slice_0008
# fix_empty_case43_day26_slice_0009
# fix_empty_case43_day26_slice_0010
# fix_empty_case43_day26_slice_0011
# fix_empty_case43_day26_slice_0012
# fix_empty_case43_day26_slice_0013
# fix_empty_case43_day26_slice_0014
# fix_empty_case43_day26_slice_0015
# fix_empty_case43_day26_slice_0016
# fix_empty_case43_day26_slice_0017
# fix_empty_case43_day26_slice_0018
# fix_empty_case43_day26_slice_0019
# fix_empty_case43_day26_slice_0020
# fix_empty_case43_day26_slice_0021
# fix_empty_case43_day26_slice_0022
# fix_empty_case43_day26_slice_0023
# fix_empty_case43_day26_slice_0024
# fix_empty_case43_day26_slice_0025
# fix_empty_case43_day26_slice_0026
# fix_empty_case43_day26_slice_0027
# fix_empty_case43_day26_slice_0028
# fix_empty_case43_day26_slice_0029
# fix_empty_case43_day26_slice_0030
# fix_empty_case43_day26_slice_0031
# fix_empty_case43_day26_slice_0032
# fix_empty_case43_day26_slice_0033
# fix_empty_case43_day26_slice_0034
# fix_empty_case43_day26_slice_0035
# fix_empty_case43_day26_slice_0036
# fix_empty_case43_day26_slice_0037
# fix_empty_case43_day26_slice_0038
# fix_empty_case43_day26_slice_0039
# fix_empty_case43_day26_slice_0040
# fix_empty_case43_day26_slice_0041
# fix_empty_case43_day26_slice_0042
# fix_empty_case43_day26_slice_0043
# fix_empty_case43_day26_slice_0044
# fix_empty_case43_day26_slice_0045
# fix_empty_case43_day26_slice_0046
# fix_empty_case43_day26_slice_0047
# fix_empty_case43_day26_slice_0048
# fix_empty_case43_day26_slice_0049
# fix_empty_case43_day26_slice_0050
# fix_empty_case43_day26_slice_0051
# fix_empty_case43_day26_slice_0052
# fix_empty_case43_day26_slice_0053
# fix_empty_case43_day26_slice_0054
# fix_empty_case43_day26_slice_0055
# fix_empty_case43_day26_slice_0056
# fix_empty_case43_day26_slice_0057
# fix_empty_case43_day26_slice_0058
# fix_empty_case43_day26_slice_0059
# fix_empty_case43_day26_slice_0060
# fix_empty_case43_day26_slice_0061
# fix_empty_case43_day26_slice_0062
# fix_empty_case43_day26_slice_0063
# fix_empty_case43_day26_slice_0064
# fix_empty_case43_day26_slice_0065
# fix_empty_case43_day26_slice_0066
# fix_empty_case43_day26_slice_0067
# fix_empty_case43_day26_slice_0068
# fix_empty_case43_day26_slice_0069
# fix_empty_case43_day26_slice_0070
# fix_empty_case43_day26_slice_0071
# fix_empty_case43_day26_slice_0072
# fix_empty_case43_day26_slice_0073
# fix_empty_case43_day26_slice_0074
# fix_empty_case43_day26_slice_0075
# fix_empty_case43_day26_slice_0076
# fix_empty_case43_day26_slice_0077
# fix_empty_case43_day26_slice_0078
# fix_empty_case43_day26_slice_0079
# fix_empty_case43_day26_slice_0080
# fix_empty_case43_day26_slice_0081
# fix_empty_case43_day26_slice_0082
# fix_empty_case43_day26_slice_0083
# fix_empty_case43_day26_slice_0084
# fix_empty_case43_day26_slice_0085
# fix_empty_case43_day26_slice_0086
# fix_empty_case43_day26_slice_0087
# fix_empty_case43_day26_slice_0088
# fix_empty_case43_day26_slice_0089
# fix_empty_case43_day26_slice_0090
# fix_empty_case43_day26_slice_0091
# fix_empty_case43_day26_slice_0092
# fix_empty_case43_day26_slice_0093
# fix_empty_case43_day26_slice_0094
# fix_empty_case43_day26_slice_0095
# fix_empty_case43_day26_slice_0096
# fix_empty_case43_day26_slice_0097
# fix_empty_case43_day26_slice_0098
# fix_empty_case43_day26_slice_0099
# fix_empty_case43_day26_slice_0100
# fix_empty_case43_day26_slice_0101
# fix_empty_case43_day26_slice_0102
# fix_empty_case43_day26_slice_0103
# fix_empty_case43_day26_slice_0104
# fix_empty_case43_day26_slice_0105
# fix_empty_case43_day26_slice_0106
# fix_empty_case43_day26_slice_0107
# fix_empty_case43_day26_slice_0108
# fix_empty_case43_day26_slice_0109
# fix_empty_case43_day26_slice_0110
# fix_empty_case43_day26_slice_0111
# fix_empty_case43_day26_slice_0112
# fix_empty_case43_day26_slice_0113
# fix_empty_case43_day26_slice_0114
# fix_empty_case43_day26_slice_0115
# fix_empty_case43_day26_slice_0116
# fix_empty_case43_day26_slice_0117
# fix_empty_case43_day26_slice_0118
# fix_empty_case43_day26_slice_0119
# fix_empty_case43_day26_slice_0120
# fix_empty_case43_day26_slice_0121
# fix_empty_case43_day26_slice_0122
# fix_empty_case43_day26_slice_0123
# fix_empty_case43_day26_slice_0124
# fix_empty_case43_day26_slice_0125
# fix_empty_case43_day26_slice_0126
# fix_empty_case43_day26_slice_0127
# fix_empty_case43_day26_slice_0128
# fix_empty_case43_day26_slice_0129
# fix_empty_case43_day26_slice_0130
# fix_empty_case43_day26_slice_0131
# fix_empty_case43_day26_slice_0132
# fix_empty_case43_day26_slice_0133
# fix_empty_case43_day26_slice_0134
# fix_empty_case43_day26_slice_0135
# fix_empty_case43_day26_slice_0136
# fix_empty_case43_day26_slice_0137
# fix_empty_case43_day26_slice_0138
# fix_empty_case43_day26_slice_0139
# fix_empty_case43_day26_slice_0140
# fix_empty_case43_day26_slice_0141
# fix_empty_case43_day26_slice_0142
# fix_empty_case43_day26_slice_0143
# fix_empty_case43_day26_slice_0144
# fix_wrong_case81_day30_slice_0001
# fix_wrong_case81_day30_slice_0001
# fix_wrong_case81_day30_slice_0001
# fix_wrong_case81_day30_slice_0002
# fix_wrong_case81_day30_slice_0002
# fix_wrong_case81_day30_slice_0002
# fix_wrong_case81_day30_slice_0003
# fix_wrong_case81_day30_slice_0003
# fix_wrong_case81_day30_slice_0003
# fix_wrong_case81_day30_slice_0004
# fix_wrong_case81_day30_slice_0004
# fix_wrong_case81_day30_slice_0004
# fix_wrong_case81_day30_slice_0005
# fix_wrong_case81_day30_slice_0005
# fix_wrong_case81_day30_slice_0005
# fix_wrong_case81_day30_slice_0006
# fix_wrong_case81_day30_slice_0006
# fix_wrong_case81_day30_slice_0006
# fix_wrong_case81_day30_slice_0007
# fix_wrong_case81_day30_slice_0007
# fix_wrong_case81_day30_slice_0007
# fix_wrong_case81_day30_slice_0008
# fix_wrong_case81_day30_slice_0008
# fix_wrong_case81_day30_slice_0008
# fix_wrong_case81_day30_slice_0009
# fix_wrong_case81_day30_slice_0009
# fix_wrong_case81_day30_slice_0009
# fix_wrong_case81_day30_slice_0010
# fix_wrong_case81_day30_slice_0010
# fix_wrong_case81_day30_slice_0010
# fix_wrong_case81_day30_slice_0011
# fix_wrong_case81_day30_slice_0011
# fix_wrong_case81_day30_slice_0011
# fix_wrong_case81_day30_slice_0012
# fix_wrong_case81_day30_slice_0012
# fix_wrong_case81_day30_slice_0012
# fix_wrong_case81_day30_slice_0013
# fix_wrong_case81_day30_slice_0013
# fix_wrong_case81_day30_slice_0013
# fix_wrong_case81_day30_slice_0014
# fix_wrong_case81_day30_slice_0014
# fix_wrong_case81_day30_slice_0014
# fix_wrong_case81_day30_slice_0015
# fix_wrong_case81_day30_slice_0015
# fix_wrong_case81_day30_slice_0015
# fix_wrong_case81_day30_slice_0016
# fix_wrong_case81_day30_slice_0016
# fix_wrong_case81_day30_slice_0016
# fix_wrong_case81_day30_slice_0017
# fix_wrong_case81_day30_slice_0017
# fix_wrong_case81_day30_slice_0017
# fix_wrong_case81_day30_slice_0018
# fix_wrong_case81_day30_slice_0018
# fix_wrong_case81_day30_slice_0018
# fix_wrong_case81_day30_slice_0019
# fix_wrong_case81_day30_slice_0019
# fix_wrong_case81_day30_slice_0019
# fix_wrong_case81_day30_slice_0020
# fix_wrong_case81_day30_slice_0020
# fix_wrong_case81_day30_slice_0020
# fix_wrong_case81_day30_slice_0021
# fix_wrong_case81_day30_slice_0021
# fix_wrong_case81_day30_slice_0021
# fix_wrong_case81_day30_slice_0022
# fix_wrong_case81_day30_slice_0022
# fix_wrong_case81_day30_slice_0022
# fix_wrong_case81_day30_slice_0023
# fix_wrong_case81_day30_slice_0023
# fix_wrong_case81_day30_slice_0023
# fix_wrong_case81_day30_slice_0024
# fix_wrong_case81_day30_slice_0024
# fix_wrong_case81_day30_slice_0024
# fix_wrong_case81_day30_slice_0025
# fix_wrong_case81_day30_slice_0025
# fix_wrong_case81_day30_slice_0025
# fix_wrong_case81_day30_slice_0026
# fix_wrong_case81_day30_slice_0026
# fix_wrong_case81_day30_slice_0026
# fix_wrong_case81_day30_slice_0027
# fix_wrong_case81_day30_slice_0027
# fix_wrong_case81_day30_slice_0027
# fix_wrong_case81_day30_slice_0028
# fix_wrong_case81_day30_slice_0028
# fix_wrong_case81_day30_slice_0028
# fix_wrong_case81_day30_slice_0029
# fix_wrong_case81_day30_slice_0029
# fix_wrong_case81_day30_slice_0029
# fix_wrong_case81_day30_slice_0030
# fix_wrong_case81_day30_slice_0030
# fix_wrong_case81_day30_slice_0030
# fix_wrong_case81_day30_slice_0031
# fix_wrong_case81_day30_slice_0031
# fix_wrong_case81_day30_slice_0031
# fix_wrong_case81_day30_slice_0032
# fix_wrong_case81_day30_slice_0032
# fix_wrong_case81_day30_slice_0032
# fix_wrong_case81_day30_slice_0033
# fix_wrong_case81_day30_slice_0033
# fix_wrong_case81_day30_slice_0033
# fix_wrong_case81_day30_slice_0034
# fix_wrong_case81_day30_slice_0034
# fix_wrong_case81_day30_slice_0034
# fix_wrong_case81_day30_slice_0035
# fix_wrong_case81_day30_slice_0035
# fix_wrong_case81_day30_slice_0035
# fix_wrong_case81_day30_slice_0036
# fix_wrong_case81_day30_slice_0036
# fix_wrong_case81_day30_slice_0036
# fix_wrong_case81_day30_slice_0037
# fix_wrong_case81_day30_slice_0037
# fix_wrong_case81_day30_slice_0037
# fix_wrong_case81_day30_slice_0038
# fix_wrong_case81_day30_slice_0038
# fix_wrong_case81_day30_slice_0038
# fix_wrong_case81_day30_slice_0039
# fix_wrong_case81_day30_slice_0039
# fix_wrong_case81_day30_slice_0039
# fix_wrong_case81_day30_slice_0040
# fix_wrong_case81_day30_slice_0040
# fix_wrong_case81_day30_slice_0040
# fix_wrong_case81_day30_slice_0041
# fix_wrong_case81_day30_slice_0041
# fix_wrong_case81_day30_slice_0041
# fix_wrong_case81_day30_slice_0042
# fix_wrong_case81_day30_slice_0042
# fix_wrong_case81_day30_slice_0042
# fix_wrong_case81_day30_slice_0043
# fix_wrong_case81_day30_slice_0043
# fix_wrong_case81_day30_slice_0043
# fix_wrong_case81_day30_slice_0044
# fix_wrong_case81_day30_slice_0044
# fix_wrong_case81_day30_slice_0044
# fix_wrong_case81_day30_slice_0045
# fix_wrong_case81_day30_slice_0045
# fix_wrong_case81_day30_slice_0045
# fix_wrong_case81_day30_slice_0046
# fix_wrong_case81_day30_slice_0046
# fix_wrong_case81_day30_slice_0046
# fix_wrong_case81_day30_slice_0047
# fix_wrong_case81_day30_slice_0047
# fix_wrong_case81_day30_slice_0047
# fix_wrong_case81_day30_slice_0048
# fix_wrong_case81_day30_slice_0048
# fix_wrong_case81_day30_slice_0048
# fix_wrong_case81_day30_slice_0049
# fix_wrong_case81_day30_slice_0049
# fix_wrong_case81_day30_slice_0049
# fix_wrong_case81_day30_slice_0050
# fix_wrong_case81_day30_slice_0050
# fix_wrong_case81_day30_slice_0050
# fix_wrong_case81_day30_slice_0051
# fix_wrong_case81_day30_slice_0051
# fix_wrong_case81_day30_slice_0051
# fix_wrong_case81_day30_slice_0052
# fix_wrong_case81_day30_slice_0052
# fix_wrong_case81_day30_slice_0052
# fix_wrong_case81_day30_slice_0053
# fix_wrong_case81_day30_slice_0053
# fix_wrong_case81_day30_slice_0053
# fix_wrong_case81_day30_slice_0054
# fix_wrong_case81_day30_slice_0054
# fix_wrong_case81_day30_slice_0054
# fix_wrong_case81_day30_slice_0055
# fix_wrong_case81_day30_slice_0055
# fix_wrong_case81_day30_slice_0055
# fix_wrong_case81_day30_slice_0056
# fix_wrong_case81_day30_slice_0056
# fix_wrong_case81_day30_slice_0056
# fix_wrong_case81_day30_slice_0057
# fix_wrong_case81_day30_slice_0057
# fix_wrong_case81_day30_slice_0057
# fix_wrong_case81_day30_slice_0058
# fix_wrong_case81_day30_slice_0058
# fix_wrong_case81_day30_slice_0058
# fix_wrong_case81_day30_slice_0059
# fix_wrong_case81_day30_slice_0059
# fix_wrong_case81_day30_slice_0059
# fix_wrong_case81_day30_slice_0060
# fix_wrong_case81_day30_slice_0060
# fix_wrong_case81_day30_slice_0060
# fix_wrong_case81_day30_slice_0061
# fix_wrong_case81_day30_slice_0061
# fix_wrong_case81_day30_slice_0061
# fix_wrong_case81_day30_slice_0062
# fix_wrong_case81_day30_slice_0062
# fix_wrong_case81_day30_slice_0062
# fix_wrong_case81_day30_slice_0063
# fix_wrong_case81_day30_slice_0063
# fix_wrong_case81_day30_slice_0063
# fix_wrong_case81_day30_slice_0064
# fix_wrong_case81_day30_slice_0064
# fix_wrong_case81_day30_slice_0064
# fix_wrong_case81_day30_slice_0065
# fix_wrong_case81_day30_slice_0065
# fix_wrong_case81_day30_slice_0065
# fix_wrong_case81_day30_slice_0066
# fix_wrong_case81_day30_slice_0066
# fix_wrong_case81_day30_slice_0066
# fix_wrong_case81_day30_slice_0067
# fix_wrong_case81_day30_slice_0067
# fix_wrong_case81_day30_slice_0067
# fix_wrong_case81_day30_slice_0068
# fix_wrong_case81_day30_slice_0068
# fix_wrong_case81_day30_slice_0068
# fix_wrong_case81_day30_slice_0069
# fix_wrong_case81_day30_slice_0069
# fix_wrong_case81_day30_slice_0069
# fix_wrong_case81_day30_slice_0070
# fix_wrong_case81_day30_slice_0070
# fix_wrong_case81_day30_slice_0070
# fix_wrong_case81_day30_slice_0071
# fix_wrong_case81_day30_slice_0071
# fix_wrong_case81_day30_slice_0071
# fix_wrong_case81_day30_slice_0072
# fix_wrong_case81_day30_slice_0072
# fix_wrong_case81_day30_slice_0072
# fix_wrong_case81_day30_slice_0073
# fix_wrong_case81_day30_slice_0073
# fix_wrong_case81_day30_slice_0073
# fix_wrong_case81_day30_slice_0074
# fix_wrong_case81_day30_slice_0074
# fix_wrong_case81_day30_slice_0074
# fix_wrong_case81_day30_slice_0075
# fix_wrong_case81_day30_slice_0075
# fix_wrong_case81_day30_slice_0075
# fix_wrong_case81_day30_slice_0076
# fix_wrong_case81_day30_slice_0076
# fix_wrong_case81_day30_slice_0076
# fix_wrong_case81_day30_slice_0077
# fix_wrong_case81_day30_slice_0077
# fix_wrong_case81_day30_slice_0077
# fix_wrong_case81_day30_slice_0078
# fix_wrong_case81_day30_slice_0078
# fix_wrong_case81_day30_slice_0078
# fix_wrong_case81_day30_slice_0079
# fix_wrong_case81_day30_slice_0079
# fix_wrong_case81_day30_slice_0079
# fix_wrong_case81_day30_slice_0080
# fix_wrong_case81_day30_slice_0080
# fix_wrong_case81_day30_slice_0080
# fix_wrong_case81_day30_slice_0081
# fix_wrong_case81_day30_slice_0081
# fix_wrong_case81_day30_slice_0081
# fix_wrong_case81_day30_slice_0082
# fix_wrong_case81_day30_slice_0082
# fix_wrong_case81_day30_slice_0082
# fix_wrong_case81_day30_slice_0083
# fix_wrong_case81_day30_slice_0083
# fix_wrong_case81_day30_slice_0083
# fix_wrong_case81_day30_slice_0084
# fix_wrong_case81_day30_slice_0084
# fix_wrong_case81_day30_slice_0084
# fix_wrong_case81_day30_slice_0085
# fix_wrong_case81_day30_slice_0085
# fix_wrong_case81_day30_slice_0085
# fix_wrong_case81_day30_slice_0086
# fix_wrong_case81_day30_slice_0086
# fix_wrong_case81_day30_slice_0086
# fix_wrong_case81_day30_slice_0087
# fix_wrong_case81_day30_slice_0087
# fix_wrong_case81_day30_slice_0087
# fix_wrong_case81_day30_slice_0088
# fix_wrong_case81_day30_slice_0088
# fix_wrong_case81_day30_slice_0088
# fix_wrong_case81_day30_slice_0089
# fix_wrong_case81_day30_slice_0089
# fix_wrong_case81_day30_slice_0089
# fix_wrong_case81_day30_slice_0090
# fix_wrong_case81_day30_slice_0090
# fix_wrong_case81_day30_slice_0090
# fix_wrong_case81_day30_slice_0091
# fix_wrong_case81_day30_slice_0091
# fix_wrong_case81_day30_slice_0091
# fix_wrong_case81_day30_slice_0092
# fix_wrong_case81_day30_slice_0092
# fix_wrong_case81_day30_slice_0092
# fix_wrong_case81_day30_slice_0093
# fix_wrong_case81_day30_slice_0093
# fix_wrong_case81_day30_slice_0093
# fix_wrong_case81_day30_slice_0094
# fix_wrong_case81_day30_slice_0094
# fix_wrong_case81_day30_slice_0094
# fix_wrong_case81_day30_slice_0095
# fix_wrong_case81_day30_slice_0095
# fix_wrong_case81_day30_slice_0095
# fix_wrong_case81_day30_slice_0096
# fix_wrong_case81_day30_slice_0096
# fix_wrong_case81_day30_slice_0096
# fix_wrong_case81_day30_slice_0097
# fix_wrong_case81_day30_slice_0097
# fix_wrong_case81_day30_slice_0097
# fix_wrong_case81_day30_slice_0098
# fix_wrong_case81_day30_slice_0098
# fix_wrong_case81_day30_slice_0098
# fix_wrong_case81_day30_slice_0099
# fix_wrong_case81_day30_slice_0099
# fix_wrong_case81_day30_slice_0099
# fix_wrong_case81_day30_slice_0100
# fix_wrong_case81_day30_slice_0100
# fix_wrong_case81_day30_slice_0100
# fix_wrong_case81_day30_slice_0101
# fix_wrong_case81_day30_slice_0101
# fix_wrong_case81_day30_slice_0101
# fix_wrong_case81_day30_slice_0102
# fix_wrong_case81_day30_slice_0102
# fix_wrong_case81_day30_slice_0102
# fix_wrong_case81_day30_slice_0103
# fix_wrong_case81_day30_slice_0103
# fix_wrong_case81_day30_slice_0103
# fix_wrong_case81_day30_slice_0104
# fix_wrong_case81_day30_slice_0104
# fix_wrong_case81_day30_slice_0104
# fix_wrong_case81_day30_slice_0105
# fix_wrong_case81_day30_slice_0105
# fix_wrong_case81_day30_slice_0105
# fix_wrong_case81_day30_slice_0106
# fix_wrong_case81_day30_slice_0106
# fix_wrong_case81_day30_slice_0106
# fix_wrong_case81_day30_slice_0107
# fix_wrong_case81_day30_slice_0107
# fix_wrong_case81_day30_slice_0107
# fix_wrong_case81_day30_slice_0108
# fix_wrong_case81_day30_slice_0108
# fix_wrong_case81_day30_slice_0108
# fix_wrong_case81_day30_slice_0109
# fix_wrong_case81_day30_slice_0109
# fix_wrong_case81_day30_slice_0109
# fix_wrong_case81_day30_slice_0110
# fix_wrong_case81_day30_slice_0110
# fix_wrong_case81_day30_slice_0110
# fix_wrong_case81_day30_slice_0111
# fix_wrong_case81_day30_slice_0111
# fix_wrong_case81_day30_slice_0111
# fix_wrong_case81_day30_slice_0112
# fix_wrong_case81_day30_slice_0112
# fix_wrong_case81_day30_slice_0112
# fix_wrong_case81_day30_slice_0113
# fix_wrong_case81_day30_slice_0113
# fix_wrong_case81_day30_slice_0113
# fix_wrong_case81_day30_slice_0114
# fix_wrong_case81_day30_slice_0114
# fix_wrong_case81_day30_slice_0114
# fix_wrong_case81_day30_slice_0115
# fix_wrong_case81_day30_slice_0115
# fix_wrong_case81_day30_slice_0115
# fix_wrong_case81_day30_slice_0116
# fix_wrong_case81_day30_slice_0116
# fix_wrong_case81_day30_slice_0116
# fix_wrong_case81_day30_slice_0117
# fix_wrong_case81_day30_slice_0117
# fix_wrong_case81_day30_slice_0117
# fix_wrong_case81_day30_slice_0118
# fix_wrong_case81_day30_slice_0118
# fix_wrong_case81_day30_slice_0118
# fix_wrong_case81_day30_slice_0119
# fix_wrong_case81_day30_slice_0119
# fix_wrong_case81_day30_slice_0119
# fix_wrong_case81_day30_slice_0120
# fix_wrong_case81_day30_slice_0120
# fix_wrong_case81_day30_slice_0120
# fix_wrong_case81_day30_slice_0121
# fix_wrong_case81_day30_slice_0121
# fix_wrong_case81_day30_slice_0121
# fix_wrong_case81_day30_slice_0122
# fix_wrong_case81_day30_slice_0122
# fix_wrong_case81_day30_slice_0122
# fix_wrong_case81_day30_slice_0123
# fix_wrong_case81_day30_slice_0123
# fix_wrong_case81_day30_slice_0123
# fix_wrong_case81_day30_slice_0124
# fix_wrong_case81_day30_slice_0124
# fix_wrong_case81_day30_slice_0124
# fix_wrong_case81_day30_slice_0125
# fix_wrong_case81_day30_slice_0125
# fix_wrong_case81_day30_slice_0125
# fix_wrong_case81_day30_slice_0126
# fix_wrong_case81_day30_slice_0126
# fix_wrong_case81_day30_slice_0126
# fix_wrong_case81_day30_slice_0127
# fix_wrong_case81_day30_slice_0127
# fix_wrong_case81_day30_slice_0127
# fix_wrong_case81_day30_slice_0128
# fix_wrong_case81_day30_slice_0128
# fix_wrong_case81_day30_slice_0128
# fix_wrong_case81_day30_slice_0129
# fix_wrong_case81_day30_slice_0129
# fix_wrong_case81_day30_slice_0129
# fix_wrong_case81_day30_slice_0130
# fix_wrong_case81_day30_slice_0130
# fix_wrong_case81_day30_slice_0130
# fix_wrong_case81_day30_slice_0131
# fix_wrong_case81_day30_slice_0131
# fix_wrong_case81_day30_slice_0131
# fix_wrong_case81_day30_slice_0132
# fix_wrong_case81_day30_slice_0132
# fix_wrong_case81_day30_slice_0132
# fix_wrong_case81_day30_slice_0133
# fix_wrong_case81_day30_slice_0133
# fix_wrong_case81_day30_slice_0133
# fix_wrong_case81_day30_slice_0134
# fix_wrong_case81_day30_slice_0134
# fix_wrong_case81_day30_slice_0134
# fix_wrong_case81_day30_slice_0135
# fix_wrong_case81_day30_slice_0135
# fix_wrong_case81_day30_slice_0135
# fix_wrong_case81_day30_slice_0136
# fix_wrong_case81_day30_slice_0136
# fix_wrong_case81_day30_slice_0136
# fix_wrong_case81_day30_slice_0137
# fix_wrong_case81_day30_slice_0137
# fix_wrong_case81_day30_slice_0137
# fix_wrong_case81_day30_slice_0138
# fix_wrong_case81_day30_slice_0138
# fix_wrong_case81_day30_slice_0138
# fix_wrong_case81_day30_slice_0139
# fix_wrong_case81_day30_slice_0139
# fix_wrong_case81_day30_slice_0139
# fix_wrong_case81_day30_slice_0140
# fix_wrong_case81_day30_slice_0140
# fix_wrong_case81_day30_slice_0140
# fix_wrong_case81_day30_slice_0141
# fix_wrong_case81_day30_slice_0141
# fix_wrong_case81_day30_slice_0141
# fix_wrong_case81_day30_slice_0142
# fix_wrong_case81_day30_slice_0142
# fix_wrong_case81_day30_slice_0142
# fix_wrong_case81_day30_slice_0143
# fix_wrong_case81_day30_slice_0143
# fix_wrong_case81_day30_slice_0143
# fix_wrong_case81_day30_slice_0144
# fix_wrong_case81_day30_slice_0144
# fix_wrong_case81_day30_slice_0144
# fix_empty_case138_day0_slice_0001
# fix_empty_case138_day0_slice_0002
# fix_empty_case138_day0_slice_0003
# fix_empty_case138_day0_slice_0004
# fix_empty_case138_day0_slice_0005
# fix_empty_case138_day0_slice_0006
# fix_empty_case138_day0_slice_0007
# fix_empty_case138_day0_slice_0008
# fix_empty_case138_day0_slice_0009
# fix_empty_case138_day0_slice_0010
# fix_empty_case138_day0_slice_0011
# fix_empty_case138_day0_slice_0012
# fix_empty_case138_day0_slice_0013
# fix_empty_case138_day0_slice_0014
# fix_empty_case138_day0_slice_0015
# fix_empty_case138_day0_slice_0016
# fix_empty_case138_day0_slice_0017
# fix_empty_case138_day0_slice_0018
# fix_empty_case138_day0_slice_0019
# fix_empty_case138_day0_slice_0020
# fix_empty_case138_day0_slice_0021
# fix_empty_case138_day0_slice_0022
# fix_empty_case138_day0_slice_0023
# fix_empty_case138_day0_slice_0024
# fix_empty_case138_day0_slice_0025
# fix_empty_case138_day0_slice_0026
# fix_empty_case138_day0_slice_0027
# fix_empty_case138_day0_slice_0028
# fix_empty_case138_day0_slice_0029
# fix_empty_case138_day0_slice_0030
# fix_empty_case138_day0_slice_0031
# fix_empty_case138_day0_slice_0032
# fix_empty_case138_day0_slice_0033
# fix_empty_case138_day0_slice_0034
# fix_empty_case138_day0_slice_0035
# fix_empty_case138_day0_slice_0036
# fix_empty_case138_day0_slice_0037
# fix_empty_case138_day0_slice_0038
# fix_empty_case138_day0_slice_0039
# fix_empty_case138_day0_slice_0040
# fix_empty_case138_day0_slice_0041
# fix_empty_case138_day0_slice_0042
# fix_empty_case138_day0_slice_0043
# fix_empty_case138_day0_slice_0044
# fix_empty_case138_day0_slice_0045
# fix_empty_case138_day0_slice_0046
# fix_empty_case138_day0_slice_0047
# fix_empty_case138_day0_slice_0048
# fix_empty_case138_day0_slice_0049
# fix_empty_case138_day0_slice_0050
# fix_empty_case138_day0_slice_0051
# fix_empty_case138_day0_slice_0052
# fix_empty_case138_day0_slice_0053
# fix_empty_case138_day0_slice_0054
# fix_empty_case138_day0_slice_0055
# fix_empty_case138_day0_slice_0056
# fix_empty_case138_day0_slice_0057
# fix_empty_case138_day0_slice_0058
# fix_empty_case138_day0_slice_0059
# fix_empty_case138_day0_slice_0060
# fix_empty_case138_day0_slice_0061
# fix_empty_case138_day0_slice_0062
# fix_empty_case138_day0_slice_0063
# fix_empty_case138_day0_slice_0064
# fix_empty_case138_day0_slice_0065
# fix_empty_case138_day0_slice_0066
# fix_empty_case138_day0_slice_0067
# fix_empty_case138_day0_slice_0068
# fix_empty_case138_day0_slice_0069
# fix_empty_case138_day0_slice_0070
# fix_empty_case138_day0_slice_0071
# fix_empty_case138_day0_slice_0072
# fix_empty_case138_day0_slice_0073
# fix_empty_case138_day0_slice_0074
# fix_empty_case138_day0_slice_0076
# fix_empty_case138_day0_slice_0077
# fix_empty_case138_day0_slice_0079
# fix_empty_case138_day0_slice_0080
# fix_empty_case138_day0_slice_0082
# fix_empty_case138_day0_slice_0083
# fix_empty_case138_day0_slice_0085
# fix_empty_case138_day0_slice_0086
# fix_empty_case138_day0_slice_0089
# fix_empty_case138_day0_slice_0092
# fix_empty_case138_day0_slice_0095
# fix_empty_case138_day0_slice_0096
# fix_empty_case138_day0_slice_0098
# fix_empty_case138_day0_slice_0099
# fix_empty_case138_day0_slice_0101
# fix_empty_case138_day0_slice_0102
# fix_empty_case138_day0_slice_0104
# fix_empty_case138_day0_slice_0105
# fix_empty_case138_day0_slice_0107
# fix_empty_case138_day0_slice_0108
# fix_empty_case138_day0_slice_0110
# fix_empty_case138_day0_slice_0111
# fix_empty_case138_day0_slice_0113
# fix_empty_case138_day0_slice_0114
# fix_empty_case138_day0_slice_0117
# fix_empty_case138_day0_slice_0118
# fix_empty_case138_day0_slice_0119
# fix_empty_case138_day0_slice_0120
# fix_empty_case138_day0_slice_0121
# fix_empty_case138_day0_slice_0122
# fix_empty_case138_day0_slice_0123
# fix_empty_case138_day0_slice_0124
# fix_empty_case138_day0_slice_0125
# fix_empty_case138_day0_slice_0126
# fix_empty_case138_day0_slice_0127
# fix_empty_case138_day0_slice_0128
# fix_empty_case138_day0_slice_0129
# fix_empty_case138_day0_slice_0130
# fix_empty_case138_day0_slice_0131
# fix_empty_case138_day0_slice_0132
# fix_empty_case138_day0_slice_0133
# fix_empty_case138_day0_slice_0134
# fix_empty_case138_day0_slice_0135
# fix_empty_case138_day0_slice_0136
# fix_empty_case138_day0_slice_0137
# fix_empty_case138_day0_slice_0138
# fix_empty_case138_day0_slice_0139
# fix_empty_case138_day0_slice_0140
# fix_empty_case138_day0_slice_0141
# fix_empty_case138_day0_slice_0142
# fix_empty_case138_day0_slice_0143
# fix_empty_case138_day0_slice_0144
#                          id        class segmentation
# 0  case123_day20_slice_0001  large_bowel          NaN
# 1  case123_day20_slice_0001  small_bowel          NaN
# 2  case123_day20_slice_0001      stomach          NaN
# 3  case123_day20_slice_0002  large_bowel          NaN
# 4  case123_day20_slice_0002  small_bowel          NaN

# %% [markdown]
# ### Csv for 3 more slices

# %%
def fix_mask(row):
    if row.id in re_mask_list:
        for i in range(len(pred_strings)):
            if row.id == pred_ids[i] and row['class'] == pred_classes[i]:
                row.segmentation = pred_strings[i]
                print(f'add_mask_for_{row.id}')
                break
    return row
fix_df = df.apply(fix_mask, axis=1)
fix_df.to_csv('/root/autodl-tmp/train_fix_more_mask.csv',index=False)
fix_df.head(5)

# %%
import shutil
shutil.make_archive('/root/save','zip','/root/save_pred')
